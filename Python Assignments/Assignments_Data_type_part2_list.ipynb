# %%
  import math

# %% [markdown]
# QUE 1

# %%
l1=[100, 200, 300, 400, 500]
print(l1[::-1])
# Out:
# [500, 400, 300, 200, 100]

# %% [markdown]
# QUE 2

# %%
l1=[i for i in range (150,250,2)]
l2=[]
for i in l1 :
   if i%4==0 :
    l2.append(i)
print (l2)
#====================
#using list comprehension
l3=[x for x in l1 if x%4==0]
print(l3)
#=====================
print ("Length of l1 : ",len(l1))
print ("Length of l2 : ",len(l2))
# Out:
# [152, 156, 160, 164, 168, 172, 176, 180, 184, 188, 192, 196, 200, 204, 208, 212, 216, 220, 224, 228, 232, 236, 240, 244, 248]
# [152, 156, 160, 164, 168, 172, 176, 180, 184, 188, 192, 196, 200, 204, 208, 212, 216, 220, 224, 228, 232, 236, 240, 244, 248]
# Length of l1 :  50
# Length of l2 :  25

# %% [markdown]
# QUE 3

# %%
aList = [1, 4, 9, 16, 25, 36, 49]
j=0
for i in aList:
  aList[j] =int(math.sqrt(i))
  j+=1
print(aList)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# QUE 4

# %%
list1 = [5, 6,7]
list2 = [0, 1]
for i in list1:
  for j in list2:
    print(i,j,", ",sep="",end="")
# Out:
# 50, 51, 60, 61, 70, 71,

# %% [markdown]
# QUE 5
# using zip

# %%
list1 = [10, 20, 30, 40]
list2 = [100, 200, 300, 400]
for i,j in zip(list1,list2[::-1]):
  print (i,j)
# Out:
# 10 400
# 20 300
# 30 200
# 40 100

# %% [markdown]
# QUE 6

# %%
list1 = ["Ashish", "", "Atharva", "Amit", "", "Revati"]
for i in list1:
  if i=="":
    list1.remove(i)
print(list1)

# using list comprehension
list2=[x for x in list1 if x!=""]
print(list2)
# Out:
# ['Ashish', 'Atharva', 'Amit', 'Revati']
# ['Ashish', 'Atharva', 'Amit', 'Revati']

# %% [markdown]
# QUE 7

# %%
list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
#print(list1[2][2][1])
num=7000
list1 [2][2].insert(2,7000)
print(list1)
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %% [markdown]
# QUE 8

# %%
list1 = ["a", "b", ["c", ["d", "e", ["f", "g"], "k"], "l"], "m", "n"]
sublist1= ["h", "i", "j"]
list1[2][1][2].extend(sublist1)
#del list1[2][1][2]
print ("Modified :",list1)
# Out:
# Modified : ['a', 'b', ['c', ['d', 'e', ['f', 'g', 'h', 'i', 'j'], 'k'], 'l'], 'm', 'n']

# %% [markdown]
# QUE 9

# %%
list1 = [5, 10, 15, 20, 25, 50, 20]
list1.remove(20) # listname.remove(element) will remove elements from lhs >>> rhs
print(list1)
# Out:
# [5, 10, 15, 25, 50, 20]

# %% [markdown]
# QUE 10

# %%
list1=[5, 20, 15, 20, 25, 50, 20]
list1=[i for i in list1 if i != 20]
# for i in list1:
#   if i==20:
#     list1.remove(i)
print(list1)
# Out:
# [5, 15, 25, 50]

# %% [markdown]
# QUE 11

# %%
num=input("Enter a Number : ")
l1=list(num)
l2=sorted(l1,reverse=True)
print("".join(l2))
# Out:
# Enter a Number : 1634
# 6431
