# %%
import math

# %% [markdown]
# QUE 1

# %%
str1=input("Enter a string")
n=len(str1)//2
print(str1[n-1:n+2])
# Out:
# Enter a stringRakeshzipPetabb
# zip

# %% [markdown]
# **QUE2**
#
# Given two strings, s1 and s2, create a new string by appending s2 in the middle of s1
# Given:
# s1 = "Ault"
# s2 = "Kelly"
# Expected Output:
# AuKellylt

# %%
str1=input("Enter a string 1  : ")
str2=input("Enter a string 2  : ")
n=len(str1)//2
print(str1[:n],str2,str1[n:],sep="")
# Out:
# Enter a string 1  : Ault
# Enter a string 2  : Kelly
# AuKellylt

# %% [markdown]
# **QUE3**
#
# two strings, s1, and s2 return a new string made of the first, middle, and last characters each input
# string
# Given:
# s1 = "America"
# s2 = "Japan"
# Expected Output:
# AJrpan

# %%
str1=input("Enter a string 1  : ")
str2=input("Enter a string 2  : ")
n1=len(str1)//2
n2=len(str2)//2
print(str1[0:1],str2[0:1],str1[n1:n1+1],str2[n2:n2+1],str1[len(str1)-1:],str2[len(str2)-1:],sep="")
# Out:
# Enter a string 1  : America
# Enter a string 2  : Japan
# AJrpan

# %% [markdown]
# **QUE4**
#
# Given an input string with the combination of the lower and upper case arrange characters in such a
# way that all lowercase letters should come first.

# %%
str1=input("Enter a string")
l1=[x for x in str1]
l2=sorted(l1,reverse=True)
print("".join(l2))
# Out:
# Enter a stringAtharvBajare
# vtrrjheaaaBA

# %% [markdown]
# **QUE5**
#
# create a third-string made of the first char of s1 then the last char of s2, Next, the second char of s1
# and second last char of s2, and so on. Any leftover chars go at the end of the result.
# Given:
# s1 = "Abc"
# s2 = "Xyz"
# Expected Output:
# AzbycX

# %%
str1=input("Enter a string 1  : ")
str2=input("Enter a string 2  : ")
l1=""
if len(str1)>len(str2):
  n=len(str2)
  for i in range(1,n+1):
    l1+=str1[i-1]
    l1+=str2[-i]
  l1+=str1[n:]
elif len(str1)<len(str2):
  n=len(str1)
  for i in range(1,n+1):
    l1+=str1[i-1]
    l1+=str2[-i]
  l1+=str2[0:len(str2)-n]
else :
  n=len(str1)
  for i in range(1,n+1):
    l1+=str1[i-1]
    l1+=str2[-i]

print(l1)
# Out:
# Enter a string 1  : XYZ
# Enter a string 2  : abcde
# XeYdZcab

# %% [markdown]
# QUE 6.Find all occurrences of “USA” from right to left in a given string ignoring the case. also display the
# starting position
#
# Given:
# str1 = "Welcome to USA. usa awesome, isn't it?
#
# Expected answer : 16, 11

# %%
str1="Welcome to USA. usa awesome, isn't it?"
print(str1.rfind("usa"))
str1.rfind("USA")
# l1=str1.split(" ")
# print(l1)
# Out:
# 16
# 11

# %% [markdown]
# 7. Find all overlapping occurrences of given substring in given string
#
# Ex.
# String = 0111
# Substring = 11
# Expected answer : 2
#
# String : ANANAAAANNN
# Substring: ANA
# Expected answer : 2
#
# String : ANANAAAANNN
# Substring: AA
# Expected answer : 3

# %%
str1=input("Enter a String")
sub1=input("Enter a substring")
n=len(str1)
[i,pos1]=[0,0]
count=0
#sub1 in str1
while n>i:
  pos1=str1.find(sub1,i)
  if pos1!=-1:
    count+=1
    i=pos1
    #print(pos1)
  else :
    break
  i+=1
print(count)
# Out:
# Enter a StringANANAAAANNN
# Enter a substringAA
# 3

# %% [markdown]
# 8. Given a string in format Emp_name:Emp_id
# If emp_is is perfect square -- > Print only vowels from emp_name
# Else if emp_id is prime -- > print alternate characters from emp_name
# Else if emp_id is odd -- > print sum of ascii values of characters in emp_name
# Else pnt
#  in this example to find prime number use sympy.isprime(num) for that import sympy

# %%
import sympy
emp=input("Enter a Employee details 'Emp_name:Emp_id' ")
l1=emp.split(":")
id=int(l1[1])

#If emp_is is perfect square -- > Print only vowels from emp_name

if int(math.sqrt(id))**2==id :
  l2=[x for x in l1[0] if x in "aeiou"]
  print(l2)
# Else if emp_id is prime -- > print alternate characters from emp_name
elif sympy.isprime(id) :
  l2=[x for x in l1[0] ]
  print(l2[::2])
#Else if emp_id is odd -- > print sum of ascii values of characters in emp_name
elif id%2 !=0:
  sum1=0
  l2=[ord(x) for x in l1[0]]
  for i in l2 :
    sum1=sum1+i
  print("The sum of all ascii ",sum1)
else:
  print("None")
# Out:
# Enter a Employee details 'Emp_name:Emp_id' aaa:15
# The sum of all ascii  291

# %% [markdown]
# 9. Find all mobile number mentioned in given paragraph of text
# Mobile number is always a 10 digit number no spaces no special characters
# Ex. Input= “this is a good number 9089786756 and 8900000000 is a desired number”
# Expected output: 9089786756 , 8900000000

# %%
str1=input("Enter a string here")
l1=str1.split(" ")
l2=[x for x in l1 if x.isnumeric()]
print(" , ".join(l2))
# Out:
# Enter a string herethis is a good number 9089786756 and 8900000000 is a desired number
# 9089786756 , 8900000000

# %% [markdown]
# 12. You are given a string S and width w.
# Your task is to wrap the string into a paragraph of width w
# Example .
# String : “ABCDEFGHIJKLIMNOQRSTUVWXYZ”
# Width: 4
# Output:
# ABCD
# EFGH
# IJKL
# IMNO
# QRST
# UVWX
# YZ

# %%
str1="ABCDEFGHIJKLIMNOQRSTUVWXYZ"
i=0
j=4
# Out:
# ['A', 'E', 'I', 'I', 'Q', 'U', 'Y']
